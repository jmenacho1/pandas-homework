# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
# See the Path of the current working directory
Path.cwd()
# Out:
# WindowsPath('C:/Users/james/Desktop/Programming/cu-nyc-fin-pt-06-2020-u-c/02-Homework/04-Pandas/Instructions/Starter_Code')

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns

csvpath = Path("../Starter_Code/whale_returns.csv")

whale_returns = pd.read_csv(csvpath)

# convert the dates to a DateTimeIndex and get rid of "Date" column

whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)

whale_returns.drop(columns=['Date'], inplace=True)

whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls

whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls

whale_returns = whale_returns.dropna().copy()
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Sort df

whale_returns = whale_returns.sort_index(ascending=True)

whale_returns.head(3)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726

# %%
# Show Clean Df

whale_returns.head(2)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns

# %%
csvpath = Path("../Starter_Code/algo_returns.csv")

algo_returns = pd.read_csv(csvpath)

# convert the dates to a DateTimeIndex and get rid of "Date" column

algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)

algo_returns.drop(columns=['Date'], inplace=True)

algo_returns.head(2)
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN

# %%
# Count nulls

algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls

algo_returns = algo_returns.dropna().copy()

algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# Sort

algo_returns = algo_returns.sort_index(ascending=True)

algo_returns.head(2)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284

# %%
# Show Clean Df
algo_returns.head(2)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices

csvpath = Path("../Starter_Code/sp500_history.csv")

sp500_history = pd.read_csv(csvpath)

# Sort ## i did this earlier then the other df's bc i wanted to fix the sort issue up front to be cleaner

sp500_history = sp500_history.sort_index(ascending=False)  # its important to put the df on the left-side of the "='sign
                                                           # or the change won't be made and it wont give an error either!
                                                           ## instead of the calc i used i cud have used: 
                                                           #sp500_history = sp500_history.reindex(index=sp500_history.index[::-1])
                                                           # as this says to flip first with last
sp500_history.head(5)                                      # garence said that formulas dont work if u have true on the right
                                                           # of = sign and have something on the left ie"sp500_history"
                                                           # not sure if this is the same for "False?"
# Out:
#           Date     Close
# 1648  1-Oct-12  $1444.49
# 1647  2-Oct-12  $1445.75
# 1646  3-Oct-12  $1450.99
# 1645  4-Oct-12  $1461.40
# 1644  5-Oct-12  $1460.93

# %%
# Count nulls   # dont really have needed to drop nulls at this point but i wanted to keep order same somewhat as previous df's

sp500_history.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
# Drop nulls

sp500_history = sp500_history.dropna().copy()
sp500_history.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
sp500_history.head(5)
# Out:
#           Date     Close
# 1648  1-Oct-12  $1444.49
# 1647  2-Oct-12  $1445.75
# 1646  3-Oct-12  $1450.99
# 1645  4-Oct-12  $1461.40
# 1644  5-Oct-12  $1460.93

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types  # get rid of $ sign and chnge "object" variable in "Close" data to "float"
# YOUR CODE HERE

sp500_history["Close"] = sp500_history["Close"].str.replace("$", "")

sp500_history["Close"] = sp500_history["Close"].astype("float")

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
# convert the dates to a DateTimeIndex and get rid of "Date" column

sp500_history.set_index(pd.to_datetime(sp500_history['Date'], infer_datetime_format=True), inplace=True)

sp500_history.drop(columns=['Date'], inplace=True)

sp500_history.head(2)
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75

# %%
# Calculate Daily Returns
# YOUR CODE HERE


sp500_daily_returns = sp500_history.pct_change() # originally i cudnt get this to work 
                                                 # til i made index datetime and dropped "date" column
                                                 # im not sure why this was the case?? but reformatting the index
                                                 # allowed it to work

sp500_daily_returns.head(2)
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872

# %%
# Count nulls   ## now you need to get rid of the null that was generated in df's first row from the % change calc

sp500_daily_returns.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
sp500_daily_returns = sp500_daily_returns.dropna().copy()
sp500_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename Column from Close to "S&P500DRs" as leaving it as "close" is inaccurate as it's now a return %
# YOUR CODE HERE
sp500_daily_returns = sp500_daily_returns.rename(columns={"Close": "S&P500DRs"})
sp500_daily_returns.head(2)
# Out:
#             S&P500DRs
# Date
# 2012-10-02   0.000872
# 2012-10-03   0.003624

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# Had all df's date index not been in the same DateTimeIndex and thus had the same index - it wudn't calc or calc correctly

joined_data_cols = pd.concat([whale_returns, algo_returns, sp500_daily_returns], axis='columns', join='inner')

joined_data_cols.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P500DRs
# Date
# 2015-03-03 -0.000949  -0.004539
# 2015-03-04  0.002416  -0.004389
# 2015-03-05  0.004323   0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns   # says cal and plot in instr but we already calc'd the daily return in the above concat df..
                       # so i think you jsut have to show the code lione to plot the daily return

joined_data_cols.plot(figsize=(10,5))

# %%
# cumulative returns

cum_joined_data_cols = (1 + joined_data_cols).cumprod() -1    # in the sat class solved exercises it has ""-1" at end 
                                                           # #8 in "Panda 2" exercises
                                                           # as do some iterations of stack overflow

cum_joined_data_cols                         # i think you need to run this w/out head or tail bc when i did
                                             # i think i got "inf" values in the bottom of the df and thus
                                             # cant seee what the cum values are for each column (ie inv. fund)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
# ...                               ...                 ...
# 2019-04-16                   0.160965           -0.213189
# 2019-04-17                   0.157602           -0.218277
# 2019-04-18                   0.159278           -0.217322
# 2019-04-22                   0.156280           -0.223061
# 2019-04-23                   0.164568           -0.220354
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# ...

# %%
# Does any portfolio outperform the S&P 500?        #  it would be nice to write a pice of loop code to output the ans. vs eyeballing
# Yes, Berkshire and Algo 1 outperf the S&P 500

# %%
cum_joined_data_cols.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P500DRs                      0
# dtype: int64

# %%
# Plot cumulative returns
cum_joined_data_cols.plot(figsize=(20,10))

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk

joined_data_cols.plot(kind="box", figsize=(20,10))

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?

joined_daily_std = joined_data_cols.std()
joined_daily_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# dtype: float64

# %%
# Which portfolios are riskier than the S&P 500?

# %%
joined_daily_std = joined_daily_std.sort_values(ascending=False)
joined_daily_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P500DRs                      0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# dtype: float64

# %%
# ans. is 1) Berkshire and 2) Tiger Global  ## the template had some true or false ans.  can do it both ways   *****

# %%
# Calculate the annualized standard deviation (252 trading days)
joined_annualized_std = joined_daily_std * np.sqrt(252)
joined_annualized_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P500DRs                      0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window   ## it should say Algo portfolios in here as well  typo
# YOUR CODE HERE

joined_data_cols_Rolling = joined_data_cols.rolling(window=21).std().plot(figsize=(20,10))
joined_data_cols_Rolling

# %%
# Construct a correlation table
# YOUR CODE HERE

joined_data_cols_correlation = joined_data_cols.corr()

joined_data_cols_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P500DRs                                     0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)


# i used 21 day to be consistent w part 1. and 4. of this section

rolling_covariance = joined_data_cols['SOROS FUND MANAGEMENT LLC'].rolling(window=21).cov(joined_data_cols['S&P500DRs'])

rolling_variance = joined_data_cols['S&P500DRs'].rolling(window=21).var()

rolling_beta = rolling_covariance / rolling_variance

rolling_beta.plot(figsize=(20, 10), title='Rolling 21-Day Beta of Soros')

# %%
# Calculate a rolling window using the exponentially weighted moving average.

joined_data_cols_ewm = joined_data_cols.ewm(halflife=21).mean().plot(figsize=(20,10), title="Exponentially Weighted Average")

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE

joined_sharpe_ratios = (joined_data_cols.mean() * 252) / (joined_data_cols.std() * np.sqrt(252))
joined_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P500DRs                      0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE

joined_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# Reading in Goog

csvpath = Path("../Starter_Code/goog_historical.csv")

goog_close_price = pd.read_csv(csvpath)

goog_close_price = goog_close_price.sort_index(ascending=False) # u have to sort first. and u need something to left of "="

# making the "Trade "DATE" column header the index of ther df
goog_close_price.set_index(pd.to_datetime(goog_close_price['Trade DATE'], infer_datetime_format=True), inplace=True)

# getting rid of extraneous "Trade DATE column
goog_close_price.drop(columns=['Trade DATE'], inplace=True)

goog_close_price.head(5)
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Read the second stock
# Reading in Aapl

csvpath = Path("../Starter_Code/aapl_historical.csv")

aapl_close_price = pd.read_csv(csvpath)

aapl_close_price = aapl_close_price.sort_index(ascending=False) # u have to sort first. and u need something to left of "="

# making the "Trade "DATE" column header the index of ther df
aapl_close_price.set_index(pd.to_datetime(aapl_close_price['Trade DATE'], infer_datetime_format=True), inplace=True)

# getting rid of extraneous "Trade DATE column
aapl_close_price.drop(columns=['Trade DATE'], inplace=True)

aapl_close_price.head(5)
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
# Read the third stock
# Reading in Cost


csvpath = Path("../Starter_Code/cost_historical.csv")

cost_close_price = pd.read_csv(csvpath)

cost_close_price = cost_close_price.sort_index(ascending=False) # u have to sort first. and u need something to left of "="

# making the "Trade "DATE" column header the index of ther df
cost_close_price.set_index(pd.to_datetime(cost_close_price['Trade DATE'], infer_datetime_format=True), inplace=True)

# getting rid of extraneous "Trade DATE column
cost_close_price.drop(columns=['Trade DATE'], inplace=True)

cost_close_price.head(5)
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
# Concatenate all stocks into a single DataFrame

joined_stock_picks = pd.concat([goog_close_price, aapl_close_price, cost_close_price], axis='rows', join='inner')

joined_stock_picks.head()       # i thought there was an error below but bc it got rid of aapl and cost
                                # but i guess thats the way that "row" join looks
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Reset the index

joined_stock_picks = joined_stock_picks.reset_index()
joined_stock_picks.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2018-05-11   GOOG  1098.26
# 1 2018-05-14   GOOG  1100.20
# 2 2018-05-15   GOOG  1079.23
# 3 2018-05-16   GOOG  1081.77
# 4 2018-05-17   GOOG  1078.59

# %%
# Pivot so that each column of prices represents a unique symbol

# %%
joined_stock_picks = joined_stock_picks.pivot_table(values="NOCP", index="Trade DATE", columns="Symbol")
joined_stock_picks.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# calc return data
joined_stock_picks_returns = joined_stock_picks.pct_change()

# Drop nulls
joined_stock_picks_returns = joined_stock_picks_returns.dropna().copy()

joined_stock_picks_returns.head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate Portfolio Returns with an equal amount of each stock

aapl_weight = 0.33
goog_weight = 0.33
cost_weight = 0.33

portfolio_weighted_returns = aapl_weight * joined_stock_picks_returns["AAPL"] + goog_weight * joined_stock_picks_returns["GOOG"]+ cost_weight * joined_stock_picks_returns["COST"]

# make sure the strings^ are exactly how they appear in the column headings in the df above ie "AAPL" NOT "aapl"
# there is a shortcut for this calc in L10R

portfolio_weighted_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.009963
# 2018-05-16    0.009309
# 2018-05-17   -0.001579
# 2018-05-18   -0.006000
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE

big_picture_returns = pd.concat([joined_data_cols, portfolio_weighted_returns], axis="columns", join="inner")

big_picture_returns = big_picture_returns.rename(columns={0:"Custom"})   # if we didnt do this then custom's columns wud have stayed "0"

big_picture_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2  S&P500DRs    Custom
# 2019-04-16  0.002899   0.000509  0.000336
# 2019-04-17 -0.005228  -0.002274  0.009199
# ...

# %%
big_picture_returns.dropna().tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2  S&P500DRs    Custom
# 2019-04-16  0.002899   0.000509  0.000336
# 2019-04-17 -0.005228  -0.002274  0.009199
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# Daily Standard Deviation   # i broke this computation out up here eventhough it wasnt asked for separately

big_picture_daily_std = big_picture_returns.std()
big_picture_daily_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.009240
# PAULSON & CO.INC.              0.007353
# TIGER GLOBAL MANAGEMENT LLC    0.014648
# BERKSHIRE HATHAWAY INC         0.015569
# Algo 1                         0.008423
# dtype: float64

# %%
# Calculate the annualized standard deviation (252 trading days)


big_picture_annualized_std = big_picture_daily_std * np.sqrt(252)
big_picture_annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# dtype: float64

# %%
# Rolling

big_picture_rolling = big_picture_returns.rolling(window=21).std().plot(figsize=(20,10))
big_picture_rolling

# %%
# Annualized Sharpe Ratios

big_picture_sharpe_ratios = (big_picture_returns.mean() * 252) / (big_picture_returns.std() * np.sqrt(252))
big_picture_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P500DRs                      0.584820
# Custom                         0.933123
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

big_picture_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
# Create a correlation analysis

big_picture_correlation = big_picture_returns.corr()
big_picture_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791962
# PAULSON & CO.INC.                             0.791962            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.478627            0.485375
# BERKSHIRE HATHAWAY INC                        0.816675            0.650758
# Algo 1                                        0.337826            0.361301
# Algo 2                                        0.862846            0.783656
# S&P500DRs                                     0.876981            0.766680
# Custom                                        0.733250            0.644210
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.478627
# PAULSON & CO.INC.                               0.485375
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.325457
# ...

# %%
# calc 21-day rolling covariance of Custom vs. S&P 500 Returns   # i used 21-day window bc that's what was used in above rolling standard dev.
# when my chart didnt look like the "starter chart" i cahnged it to 30 day then 60-day to see if i cud get the same illustrative represenation.
# when i ran the 60-day i did - so i knew that my code was correct.  I changed it back to 21-day to be consistent

rolling_covariance_custom = big_picture_returns['Custom'].rolling(window=21).cov(big_picture_returns['S&P500DRs'])

# calc 21-day rolling Variance of S&P500("S&P500DRs") Returns    # i used 21-day window bc that's what was used in above rolling standard dev.

rolling_variance_snp500 = big_picture_returns['S&P500DRs'].rolling(window=21).var()

# Calculate 21-Day Rolling Beta of Custom

rolling_beta_custom = rolling_covariance_custom / rolling_variance_snp500

rolling_beta_custom.plot(figsize=(20, 10), title='Rolling 21-Day Beta of Custom')
